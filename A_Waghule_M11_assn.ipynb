# %% [markdown]
# ### Introduction
#
# - Goal: To compare the performance of a decision tree vs. a random forest models
# - Dataset: It contains information pertaining to NY State High School graduation metrics for the 2018-2019 school year
# https://raw.githubusercontent.com/getfitwithapurv/datascience/main/M11_Data.csv
# - Steps:
# 1. Import the datset from github repository and do EDA
# 2. Create a new categorical indicator variable derived from the content of the reg_pct attribute
# 3. Remove the “reg_pct” and “reg_cnt” attributes from your dataframe.
# 4. Analyze the distribution of the newly created “reg_pct_level” indicator value
# 5. Select explanatory and response Variable for modeling
# 6. Split the data into training and testing subsets, use the training subset to construct two different decision tree models and two different random forest models
# 7. Use different metrics to compare/contrast the models
# 8. Conclusion

# %%
# load the pandas library
import pandas as pd
import numpy as np
#importing required libraries for visualization
import seaborn as sns
import matplotlib.pyplot as plt
# importing dataset from github. 
# This data set contains information pertaining to NY State High School graduation metrics for the 2018-2019 school year
filename = "https://raw.githubusercontent.com/getfitwithapurv/datascience/main/M11_Data.csv"
df = pd.read_csv(filename)
df.head()
# Out:
#   report_school_year  aggregation_index aggregation_type  \
# 0            2018-19                  3         District
# 1            2018-19                  3         District
# 2            2018-19                  3         District
# 3            2018-19                  3         District
# 4            2018-19                  3         District
#
#               aggregation_name  nrc_code                   nrc_desc  \
# 0  ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
# 1  ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
# 2  ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
# 3  ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
# 4  ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
#
#    county_code county_name  nyc_ind                     membership_desc  \
# 0            1      ALBANY        0  2013 Total Cohort - 6 Year Outcome
# 1            1      ALBANY        0  2013 Total Cohort - 6 Year Outcome
# 2            1      ALBANY        0  2013 Total Cohort - 6 Year Outcome
# 3            1      ALBANY        0  2013 Total Cohort - 6 Year Outcome
# 4            1      ALBANY        0  2013 Total Cohort - 6 Year Outcome
#
#    subgroup_code                  subgroup_name enroll_cnt grad_cnt grad_pct  \
# 0              1                   All Students        658      464      71%
# 1              2                         Female        324      246      76%
# 2              3                           Male        334      218      65%
# 3              4  American Indian/Alaska Native          -        -        -
# 4              5                          Black        367      248      68%
#
#   reg_cnt reg_pct dropout_cnt dropout_pct
# 0     310     47%         148         22%
# 1     169     52%          65         20%
# 2     141     42%          83         25%
# 3       -       -           -           -
# 4     183     50%          91         25%

# %% [markdown]
# ### Exploratory Data Analysis, Data Preparation, Prepped Data Review

# %%
# checking datatype and null values of data set
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73152 entries, 0 to 73151
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   report_school_year  73152 non-null  object
#  1   aggregation_index   73152 non-null  int64
#  2   aggregation_type    73152 non-null  object
#  3   aggregation_name    73152 non-null  object
#  4   nrc_code            73152 non-null  int64
#  5   nrc_desc            73152 non-null  object
#  6   county_code         73152 non-null  int64
#  7   county_name         73152 non-null  object
#  8   nyc_ind             73152 non-null  int64
#  9   membership_desc     73152 non-null  object
#  10  subgroup_code       73152 non-null  int64
#  11  subgroup_name       73152 non-null  object
#  12  enroll_cnt          73152 non-null  object
#  13  grad_cnt            73152 non-null  object
#  14  grad_pct            73152 non-null  object
#  15  reg_cnt             73152 non-null  object
#  16  reg_pct             73152 non-null  object
#  17  dropout_cnt         73152 non-null  object
#  18  dropout_pct         73152 non-null  object
# dtypes: int64(5), object(14)
# memory usage: 10.6+ MB

# %%
df.isin(['-']).sum(axis=0) #checking # of "-" values in dataset
# Out:
# report_school_year        0
# aggregation_index         0
# aggregation_type          0
# aggregation_name          0
# nrc_code                  0
# nrc_desc                  0
# county_code               0
# county_name               0
# nyc_ind                   0
# membership_desc           0
# subgroup_code             0
# subgroup_name             0
# enroll_cnt            33478
# grad_cnt              33478
# grad_pct              33478
# reg_cnt               33478
# reg_pct               33478
# dropout_cnt           33478
# dropout_pct           33478
# dtype: int64

# %% [markdown]
# Firstly removing rows containing "-" value  then converting % columns into float

# %%
df= df[df["enroll_cnt"].str.contains("-")==False] #removed rows containing "-". Rows reduced from 73152 to 39674

# %%
df['reg_pct'] = df['reg_pct'].str.rstrip('%').astype("float") #removing % and converting column to float

# %%
df['grad_pct'] = df['grad_pct'].str.rstrip('%').astype("float") #removing % and converting column to float

# %%
df['dropout_pct'] = df['dropout_pct'].str.rstrip('%').astype("float") #removing % and converting column to float

# %%
df.head() #sanity check
# Out:
#   report_school_year  aggregation_index aggregation_type  \
# 0            2018-19                  3         District
# 1            2018-19                  3         District
# 2            2018-19                  3         District
# 4            2018-19                  3         District
# 5            2018-19                  3         District
#
#               aggregation_name  nrc_code                   nrc_desc  \
# 0  ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
# 1  ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
# 2  ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
# 4  ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
# 5  ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
#
#    county_code county_name  nyc_ind                     membership_desc  \
# 0            1      ALBANY        0  2013 Total Cohort - 6 Year Outcome
# 1            1      ALBANY        0  2013 Total Cohort - 6 Year Outcome
# 2            1      ALBANY        0  2013 Total Cohort - 6 Year Outcome
# 4            1      ALBANY        0  2013 Total Cohort - 6 Year Outcome
# 5            1      ALBANY        0  2013 Total Cohort - 6 Year Outcome
#
#    subgroup_code subgroup_name enroll_cnt grad_cnt  grad_pct reg_cnt  reg_pct  \
# 0              1  All Students        658      464      71.0     310     47.0
# 1              2        Female        324      246      76.0     169     52.0
# 2              3          Male        334      218      65.0     141     42.0
# 4              5         Black        367      248      68.0     183     50.0
# 5              6      Hispanic         98       58      59.0      40     41.0
#
#   dropout_cnt  dropout_pct
# 0         148         22.0
# 1          65         20.0
# 2          83         25.0
# 4          91         25.0
# 5          28         29.0

# %%
df.shape # 39674 rows and 19 columns (45% rows are removed)
# Out:
# (39674, 19)

# %%
df.isin(['-']).sum(axis=0) #checking if "-" value still exists
# Out:
# report_school_year    0
# aggregation_index     0
# aggregation_type      0
# aggregation_name      0
# nrc_code              0
# nrc_desc              0
# county_code           0
# county_name           0
# nyc_ind               0
# membership_desc       0
# subgroup_code         0
# subgroup_name         0
# enroll_cnt            0
# grad_cnt              0
# grad_pct              0
# reg_cnt               0
# reg_pct               0
# dropout_cnt           0
# dropout_pct           0
# dtype: int64

# %% [markdown]
# No "-" value now in dataset

# %%
df['reg_pct'].isnull #checking null values in 'reg_pct' column
# Out:
# <bound method Series.isnull of 0        47.0
# 1        52.0
# 2        42.0
# 4        50.0
# 5        41.0
#          ...
# 73138    56.0
# 73142    67.0
# 73143    15.0
# 73145    61.0
# 73146    50.0
# Name: reg_pct, Length: 39674, dtype: float64>

# %%
df.head(10)
# Out:
#    report_school_year  aggregation_index aggregation_type  \
# 0             2018-19                  3         District
# 1             2018-19                  3         District
# 2             2018-19                  3         District
# 4             2018-19                  3         District
# 5             2018-19                  3         District
# 6             2018-19                  3         District
# 7             2018-19                  3         District
# 9             2018-19                  3         District
# 10            2018-19                  3         District
# 11            2018-19                  3         District
#
#                aggregation_name  nrc_code                   nrc_desc  \
# 0   ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
# 1   ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
# 2   ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
# 4   ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
# 5   ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
# 6   ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
# 7   ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
# 9   ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
# 10  ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
# 11  ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
#
#     county_code county_name  nyc_ind                     membership_desc  \
# 0             1      ALBANY        0  2013 Total Cohort - 6 Year Outcome
# 1             1      ALBANY        0  2013 Total Cohort - 6 Year Outcome
# 2             1      ALBANY        0  2013 Total Cohort - 6 Year Outcome
# 4             1      ALBANY        0  2013 Total Cohort - 6 Year Outcome
# 5             1      ALBANY        0  2013 Total Cohort - 6 Year Outcome
# 6             1      ALBANY        0  2013 Total Cohort - 6 Year Outcome
# 7             1      ALBANY        0  2013 Total Cohort - 6 Year Outcome
# 9             1      ALBANY        0  2013 Total Cohort - 6 Year Outcome
# 10            1      ALBANY        0  2013 Total Cohort - 6 Year Outcome
# 11            1      ALBANY        0  2013 Total Cohort - 6 Year Outcome
#
#     subgroup_code                 subgroup_name enroll_cnt grad_cnt  grad_pct  \
# 0               1                  All Students        658      464      71.0
# 1               2                        Female        324      246      76.0
# 2               3                          Male        334      218      65.0
# 4               5                         Black        367      248      68.0
# 5               6                      Hispanic         98       58      59.0
# 6               7        Asian/Pacific Islander         46       38      83.0
# 7               8                         White        130      105      81.0
# 9              10    General Education Students        544      415      76.0
# 10             11    Students with Disabilities        114       49      43.0
# 11             12  Not English Language Learner        613      442      72.0
#
#    reg_cnt  reg_pct dropout_cnt  dropout_pct
# 0      310     47.0         148         22.0
# 1      169     52.0          65         20.0
# 2      141     42.0          83         25.0
# 4      183     50.0          91         25.0
# 5       40     41.0          28         29.0
# 6       26     57.0           8         17.0
# 7       50     38.0          19         15.0
# 9      297     55.0         114         21.0
# 10      13     11.0          34         30.0
# 11     293     48.0         128         21.0

# %%
#Convert Multiple Columns to Integer
df[['enroll_cnt', 'grad_cnt', 'reg_cnt', 'dropout_cnt']]= df[['enroll_cnt', 'grad_cnt', 'reg_cnt', 'dropout_cnt']].astype(int)

# %%
df.info() #sanity check
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39674 entries, 0 to 73146
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   report_school_year  39674 non-null  object
#  1   aggregation_index   39674 non-null  int64
#  2   aggregation_type    39674 non-null  object
#  3   aggregation_name    39674 non-null  object
#  4   nrc_code            39674 non-null  int64
#  5   nrc_desc            39674 non-null  object
#  6   county_code         39674 non-null  int64
#  7   county_name         39674 non-null  object
#  8   nyc_ind             39674 non-null  int64
#  9   membership_desc     39674 non-null  object
#  10  subgroup_code       39674 non-null  int64
#  11  subgroup_name       39674 non-null  object
#  12  enroll_cnt          39674 non-null  int64
#  13  grad_cnt            39674 non-null  int64
#  14  grad_pct            39674 non-null  float64
#  15  reg_cnt             39674 non-null  int64
#  16  reg_pct             39674 non-null  float64
#  17  dropout_cnt         39674 non-null  int64
#  18  dropout_pct         39674 non-null  float64
# dtypes: float64(3), int64(9), object(7)
# memory usage: 6.1+ MB

# %%
df.describe()
# Out:
#        aggregation_index      nrc_code   county_code       nyc_ind  \
# count            39674.0  39674.000000  39674.000000  39674.000000
# mean                 3.0      4.456269     36.774613      0.085245
# std                  0.0      1.367020     20.063556      0.279249
# min                  3.0      1.000000      1.000000      0.000000
# 25%                  3.0      4.000000     21.000000      0.000000
# 50%                  3.0      5.000000     35.000000      0.000000
# 75%                  3.0      5.000000     58.000000      0.000000
# max                  3.0      6.000000     68.000000      1.000000
#
#        subgroup_code    enroll_cnt      grad_cnt      grad_pct       reg_cnt  \
# count   39674.000000  39674.000000  39674.000000  39674.000000  39674.000000
# mean        8.833795    192.120079    161.178354     84.406614     86.804708
# std         5.768892    439.972474    361.294773     15.679500    225.795826
# min         1.000000      5.000000      0.000000      0.000000      0.000000
# 25%         3.000000     25.000000     20.000000     79.000000     10.000000
# 50%         9.000000     66.000000     57.000000     89.000000     27.000000
# 75%        15.000000    179.000000    156.000000     95.000000     69.000000
# max        25.000000   9176.000000   7540.000000    100.000000   4752.000000
#
#             reg_pct   dropout_cnt   dropout_pct
# count  39674.000000  39674.000000  39674.000000
# mean      43.371125     16.239225      7.963049
# std       17.124891     50.129834      9.658698
# min        0.000000      0.000000      0.000000
# 25%       33.000000      1.000000      1.000000
# 50%       43.000000      3.000000      5.000000
# 75%       53.000000      9.000000     11.000000
# max      100.000000   1091.000000    100.000000

# %%
df.head(5) #sanity check
# Out:
#   report_school_year  aggregation_index aggregation_type  \
# 0            2018-19                  3         District
# 1            2018-19                  3         District
# 2            2018-19                  3         District
# 4            2018-19                  3         District
# 5            2018-19                  3         District
#
#               aggregation_name  nrc_code                   nrc_desc  \
# 0  ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
# 1  ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
# 2  ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
# 4  ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
# 5  ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
#
#    county_code county_name  nyc_ind                     membership_desc  \
# 0            1      ALBANY        0  2013 Total Cohort - 6 Year Outcome
# 1            1      ALBANY        0  2013 Total Cohort - 6 Year Outcome
# 2            1      ALBANY        0  2013 Total Cohort - 6 Year Outcome
# 4            1      ALBANY        0  2013 Total Cohort - 6 Year Outcome
# 5            1      ALBANY        0  2013 Total Cohort - 6 Year Outcome
#
#    subgroup_code subgroup_name  enroll_cnt  grad_cnt  grad_pct  reg_cnt  \
# 0              1  All Students         658       464      71.0      310
# 1              2        Female         324       246      76.0      169
# 2              3          Male         334       218      65.0      141
# 4              5         Black         367       248      68.0      183
# 5              6      Hispanic          98        58      59.0       40
#
#    reg_pct  dropout_cnt  dropout_pct
# 0     47.0          148         22.0
# 1     52.0           65         20.0
# 2     42.0           83         25.0
# 4     50.0           91         25.0
# 5     41.0           28         29.0

# %%
#defining function filter to categorize data of reg_pct attribute
def perct(x):
    if x <= 33.33:
        return 'low'
    if (x > 33.33 and x <= 66.66):
        return 'medium'
    if x > 66.66:
        return 'high'

# %%
#applying the perct function to 'reg_pct' column 
# To create a new categorical indicator variable derived from the content of the reg_pct attribute
df['reg_pct_level'] = df['reg_pct'].apply(perct)

# %%
df.head() #sanity check
# Out:
#   report_school_year  aggregation_index aggregation_type  \
# 0            2018-19                  3         District
# 1            2018-19                  3         District
# 2            2018-19                  3         District
# 4            2018-19                  3         District
# 5            2018-19                  3         District
#
#               aggregation_name  nrc_code                   nrc_desc  \
# 0  ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
# 1  ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
# 2  ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
# 4  ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
# 5  ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
#
#    county_code county_name  nyc_ind                     membership_desc  \
# 0            1      ALBANY        0  2013 Total Cohort - 6 Year Outcome
# 1            1      ALBANY        0  2013 Total Cohort - 6 Year Outcome
# 2            1      ALBANY        0  2013 Total Cohort - 6 Year Outcome
# 4            1      ALBANY        0  2013 Total Cohort - 6 Year Outcome
# 5            1      ALBANY        0  2013 Total Cohort - 6 Year Outcome
#
#    subgroup_code subgroup_name  enroll_cnt  grad_cnt  grad_pct  reg_cnt  \
# 0              1  All Students         658       464      71.0      310
# 1              2        Female         324       246      76.0      169
# 2              3          Male         334       218      65.0      141
# 4              5         Black         367       248      68.0      183
# 5              6      Hispanic          98        58      59.0       40
#
#    reg_pct  dropout_cnt  dropout_pct reg_pct_level
# 0     47.0          148         22.0        medium
# 1     52.0           65         20.0        medium
# 2     42.0           83         25.0        medium
# 4     50.0           91         25.0        medium
# 5     41.0           28         29.0        medium

# %%
plt.figure(figsize=(12,10))
corr = df.corr()
sns.heatmap(corr, cmap="YlGnBu",xticklabels=corr.columns.values, yticklabels=corr.columns.values, annot=True)
plt.show()
# Plotting heatmap to see correlation bewteen the features.

# %%
df["report_school_year"].unique() # data is only for the year 2018-19
# Out:
# array(['2018-19'], dtype=object)

# %% [markdown]
# only 1, can be removed

# %%
df["subgroup_name"].unique() #Text description of student subgrouping
# Out:
# array(['All Students', 'Female', 'Male', 'Black', 'Hispanic',
#        'Asian/Pacific Islander', 'White', 'General Education Students',
#        'Students with Disabilities', 'Not English Language Learner',
#        'English Language Learner', 'Economically Disadvantaged',
#        'Not Economically Disadvantaged', 'Homeless', 'Not Homeless',
#        'Formerly English Language Learner', 'Multiracial',
#        'American Indian/Alaska Native', 'Migrant', 'Not Migrant',
#        'In Foster Care', 'Not in Foster Care', 'Parent in Armed Forces',
#        'Parent Not in Armed Forces'], dtype=object)

# %%
len(pd.unique(df["subgroup_name"])) #count of student subgrouping name
# Out:
# 24

# %%
len(pd.unique(df["subgroup_code"])) #count of student subgrouping code
# Out:
# 24

# %% [markdown]
# Both correlate to each other hence one of them can be removed

# %%
# setting the dimensions of the plot
fig, ax = plt.subplots(figsize=(8, 8))
sns.countplot(data=df, y='subgroup_name',ax=ax)
# Out:
# <AxesSubplot:xlabel='count', ylabel='subgroup_name'>

# %%
len(pd.unique(df["nrc_desc"])) #count of  the type of school district
# Out:
# 6

# %%
df["nrc_desc"].unique() #Text description of the type of school district
# Out:
# array(['Urban-Suburban High Needs', 'Average Needs', 'Low Needs',
#        'Rural High Needs', 'Buffalo  Rochester  Yonkers  Syracuse', 'NYC'],
#       dtype=object)

# %%
sns.countplot(data=df, y='nrc_desc')
# Out:
# <AxesSubplot:xlabel='count', ylabel='nrc_desc'>

# %%
len(pd.unique(df["nrc_code"]))
# Out:
# 6

# %%
df['nrc_code'].value_counts()
# Out:
# 5    18260
# 6     7136
# 4     7048
# 3     3412
# 1     3382
# 2      436
# Name: nrc_code, dtype: int64

# %%
len(pd.unique(df["aggregation_name"])) #count of unique school names
# Out:
# 677

# %%
# pandas count distinct values in column
aggregation_namedf = df['aggregation_name'].value_counts()
aggregation_namedf
# Out:
# SYRACUSE CITY SCHOOL DISTRICT                         116
# NEW YORK CITY GEOGRAPHIC DISTRICT # 3                 108
# NEW YORK CITY GEOGRAPHIC DISTRICT #25                 108
# NEW YORK CITY GEOGRAPHIC DISTRICT # 9                 108
# NEW YORK CITY GEOGRAPHIC DISTRICT #21                 108
#                                                      ...
# KIRYAS JOEL VILLAGE UNION FREE SCHOOL DISTRICT          4
# FISHERS ISLAND UNION FREE SCHOOL DISTRICT               4
# GREENBURGH-NORTH CASTLE UNION FREE SCHOOL DISTRICT      2
# LONG LAKE CENTRAL SCHOOL DISTRICT                       2
# BERKSHIRE UNION FREE SCHOOL DISTRICT                    2
# Name: aggregation_name, Length: 677, dtype: int64

# %%
len(pd.unique(df["county_name"])) #count of applicable NY State county
# Out:
# 62

# %%
len(pd.unique(df["aggregation_type"])) #count of unique aggregation type
# Out:
# 1

# %% [markdown]
# Only 1, Can be removed

# %%
len(pd.unique(df["aggregation_index"])) #count of unique aggregation index
# Out:
# 1

# %% [markdown]
# Only 1, Can be removed

# %%
len(pd.unique(df["nyc_ind"])) #count of unique aggregation index
# Out:
# 2

# %%
df["nyc_ind"].unique()
# Out:
# array([0, 1])

# %%
df["membership_desc"].unique()
# Out:
# array(['2013 Total Cohort - 6 Year Outcome',
#        '2014 Total Cohort - 5 Year Outcome',
#        '2015 Total Cohort - 4 Year Outcome',
#        '2014 Total Cohort - 5 Year Outcome - August 2019',
#        '2015 Total Cohort - 4 Year Outcome - August 2019',
#        '2013 Total Cohort - 6 Year Outcome - August 2019'], dtype=object)

# %%
#removing “reg_pct” and “reg_cnt” attributes from the dataframe
df = df.drop(columns=['reg_pct', 'reg_cnt', 'dropout_cnt', 'grad_cnt', 'report_school_year', 'aggregation_index', 'aggregation_type', 'nrc_desc', 'county_code', 'subgroup_name'])

# %%
df.head() #sanity check
# Out:
#               aggregation_name  nrc_code county_name  nyc_ind  \
# 0  ALBANY CITY SCHOOL DISTRICT         3      ALBANY        0
# 1  ALBANY CITY SCHOOL DISTRICT         3      ALBANY        0
# 2  ALBANY CITY SCHOOL DISTRICT         3      ALBANY        0
# 4  ALBANY CITY SCHOOL DISTRICT         3      ALBANY        0
# 5  ALBANY CITY SCHOOL DISTRICT         3      ALBANY        0
#
#                       membership_desc  subgroup_code  enroll_cnt  grad_pct  \
# 0  2013 Total Cohort - 6 Year Outcome              1         658      71.0
# 1  2013 Total Cohort - 6 Year Outcome              2         324      76.0
# 2  2013 Total Cohort - 6 Year Outcome              3         334      65.0
# 4  2013 Total Cohort - 6 Year Outcome              5         367      68.0
# 5  2013 Total Cohort - 6 Year Outcome              6          98      59.0
#
#    dropout_pct reg_pct_level
# 0         22.0        medium
# 1         20.0        medium
# 2         25.0        medium
# 4         25.0        medium
# 5         29.0        medium

# %%
# count plot on single categorical variable
plt.figure(figsize=(8, 5))
ax = sns.countplot(x = 'reg_pct_level', data = df)
plt.title('Reg Percentage Level')
#display the percentage above the bar 
total = len(df['reg_pct_level'])
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2., height + 3,
            '{:1.3f}%'.format(100*(height/total)),
            ha="center")

# %%
plt.figure(figsize=(12,6))
corr = df.corr()
sns.heatmap(corr, cmap="YlGnBu",xticklabels=corr.columns.values, yticklabels=corr.columns.values, annot=True)
plt.show()
# Plotting heatmap to see correlation bewteen the features.

# %%
df.hist(column='enroll_cnt')
# Out:
# array([[<AxesSubplot:title={'center':'enroll_cnt'}>]], dtype=object)

# %%
df.hist(column='grad_pct')
# Out:
# array([[<AxesSubplot:title={'center':'grad_pct'}>]], dtype=object)

# %%
df.hist(column='dropout_pct')
# Out:
# array([[<AxesSubplot:title={'center':'dropout_pct'}>]], dtype=object)

# %%
# importing power_transform for normalization of numerical values 
from sklearn.preprocessing import power_transform

# %%
df2 = df[['enroll_cnt','grad_pct','dropout_pct']].copy() #making new dataframe fro standardization of numeric variables

# %%
# columns to list 
numericsc = list(df2.columns)

# %%
#normalizing numeric variables
standardized_data = pd.DataFrame(power_transform(df2[numericsc]), columns = numericsc)
standardized_data
# Out:
#        enroll_cnt  grad_pct  dropout_pct
# 0        1.556674 -1.203165     1.382375
# 1        1.117188 -0.905171     1.290762
# 2        1.136630 -1.494472     1.506749
# 3        1.196556 -1.357296     1.506749
# 4        0.309499 -1.722803     1.653244
# ...           ...       ...          ...
# 39669   -0.430522 -1.307864     1.506749
# 39670   -0.212331  0.250897     0.655759
# 39671   -1.231135 -2.261979     2.122271
# 39672   -0.497330 -1.256503     1.337539
# 39673   -0.624445 -0.699582     0.956831
#
# [39674 rows x 3 columns]

# %%
standardized_data.hist(column='enroll_cnt') #sanity check
# Out:
# array([[<AxesSubplot:title={'center':'enroll_cnt'}>]], dtype=object)

# %%
standardized_data.hist(column='grad_pct') #sanity check
# Out:
# array([[<AxesSubplot:title={'center':'grad_pct'}>]], dtype=object)

# %%
standardized_data.hist(column='dropout_pct') #sanity check
# Out:
# array([[<AxesSubplot:title={'center':'dropout_pct'}>]], dtype=object)

# %%
#creating new df to add the normalized data to it which can be used for modeling 
df3 = df[['aggregation_name', 'nrc_code', 'county_name', 'nyc_ind', 'membership_desc', 'subgroup_code', 'reg_pct_level']].copy()

# %%
df3.head()
# Out:
#               aggregation_name  nrc_code county_name  nyc_ind  \
# 0  ALBANY CITY SCHOOL DISTRICT         3      ALBANY        0
# 1  ALBANY CITY SCHOOL DISTRICT         3      ALBANY        0
# 2  ALBANY CITY SCHOOL DISTRICT         3      ALBANY        0
# 4  ALBANY CITY SCHOOL DISTRICT         3      ALBANY        0
# 5  ALBANY CITY SCHOOL DISTRICT         3      ALBANY        0
#
#                       membership_desc  subgroup_code reg_pct_level
# 0  2013 Total Cohort - 6 Year Outcome              1        medium
# 1  2013 Total Cohort - 6 Year Outcome              2        medium
# 2  2013 Total Cohort - 6 Year Outcome              3        medium
# 4  2013 Total Cohort - 6 Year Outcome              5        medium
# 5  2013 Total Cohort - 6 Year Outcome              6        medium

# %%
df4 = pd.concat([standardized_data, df3], axis=1, join='inner') #joining the dataframes

# %%
df4.head()
# Out:
#    enroll_cnt  grad_pct  dropout_pct             aggregation_name  nrc_code  \
# 0    1.556674 -1.203165     1.382375  ALBANY CITY SCHOOL DISTRICT         3
# 1    1.117188 -0.905171     1.290762  ALBANY CITY SCHOOL DISTRICT         3
# 2    1.136630 -1.494472     1.506749  ALBANY CITY SCHOOL DISTRICT         3
# 4    0.309499 -1.722803     1.653244  ALBANY CITY SCHOOL DISTRICT         3
# 5   -0.244340 -0.391408     1.136820  ALBANY CITY SCHOOL DISTRICT         3
#
#   county_name  nyc_ind                     membership_desc  subgroup_code  \
# 0      ALBANY        0  2013 Total Cohort - 6 Year Outcome              1
# 1      ALBANY        0  2013 Total Cohort - 6 Year Outcome              2
# 2      ALBANY        0  2013 Total Cohort - 6 Year Outcome              3
# 4      ALBANY        0  2013 Total Cohort - 6 Year Outcome              5
# 5      ALBANY        0  2013 Total Cohort - 6 Year Outcome              6
#
#   reg_pct_level
# 0        medium
# 1        medium
# 2        medium
# 4        medium
# 5        medium

# %%
#Assign 1,2,3 for low, medium and high values respectively in reg_pct_level column of dataset 
df4['reg_pct_level'] = df4['reg_pct_level'].map({'low': 1, 'medium': 2, 'high':3})

# %%
# Creating dummy variables from categorical columns:
newdf = pd.get_dummies(df4, columns=['aggregation_name','county_name','membership_desc'])
newdf.head() #first dataframe for modeling
# Out:
#    enroll_cnt  grad_pct  dropout_pct  nrc_code  nyc_ind  subgroup_code  \
# 0    1.556674 -1.203165     1.382375         3        0              1
# 1    1.117188 -0.905171     1.290762         3        0              2
# 2    1.136630 -1.494472     1.506749         3        0              3
# 4    0.309499 -1.722803     1.653244         3        0              5
# 5   -0.244340 -0.391408     1.136820         3        0              6
#
#    reg_pct_level  aggregation_name_ADIRONDACK CENTRAL SCHOOL DISTRICT  \
# 0              2                                                  0
# 1              2                                                  0
# 2              2                                                  0
# 4              2                                                  0
# 5              2                                                  0
#
#    aggregation_name_AFTON CENTRAL SCHOOL DISTRICT  \
# 0                                               0
# 1                                               0
# 2                                               0
# 4                                               0
# 5                                               0
#
#    aggregation_name_AKRON CENTRAL SCHOOL DISTRICT  ...  county_name_ONEIDA  \
# 0                                               0  ...                   0
# 1                                               0  ...                   0
# 2                                               0  ...                   0
# 4                                               0  ...                   0
# 5                                               0  ...                   0
#
#    county_name_ONONDAGA  county_name_QUEENS  county_name_RICHMOND  \
# 0                     0                   0                     0
# 1                     0                   0                     0
# 2                     0                   0                     0
# 4                     0                   0                     0
# 5                     0                   0                     0
#
#    membership_desc_2013 Total Cohort - 6 Year Outcome  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 4                                                  1
# 5                                                  1
#
#    membership_desc_2013 Total Cohort - 6 Year Outcome - August 2019  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 4                                                  0
# 5                                                  0
#
#    membership_desc_2014 Total Cohort - 5 Year Outcome  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 4                                                  0
# 5                                                  0
#
#    membership_desc_2014 Total Cohort - 5 Year Outcome - August 2019  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 4                                                  0
# 5                                                  0
#
#    membership_desc_2015 Total Cohort - 4 Year Outcome  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 4                                                  0
# 5                                                  0
#
#    membership_desc_2015 Total Cohort - 4 Year Outcome - August 2019
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 4                                                  0
# 5                                                  0
#
# [5 rows x 418 columns]

# %%
df.head()
# Out:
#               aggregation_name  nrc_code county_name  nyc_ind  \
# 0  ALBANY CITY SCHOOL DISTRICT         3      ALBANY        0
# 1  ALBANY CITY SCHOOL DISTRICT         3      ALBANY        0
# 2  ALBANY CITY SCHOOL DISTRICT         3      ALBANY        0
# 4  ALBANY CITY SCHOOL DISTRICT         3      ALBANY        0
# 5  ALBANY CITY SCHOOL DISTRICT         3      ALBANY        0
#
#                       membership_desc  subgroup_code  enroll_cnt  grad_pct  \
# 0  2013 Total Cohort - 6 Year Outcome              1         658      71.0
# 1  2013 Total Cohort - 6 Year Outcome              2         324      76.0
# 2  2013 Total Cohort - 6 Year Outcome              3         334      65.0
# 4  2013 Total Cohort - 6 Year Outcome              5         367      68.0
# 5  2013 Total Cohort - 6 Year Outcome              6          98      59.0
#
#    dropout_pct reg_pct_level
# 0         22.0        medium
# 1         20.0        medium
# 2         25.0        medium
# 4         25.0        medium
# 5         29.0        medium

# %%
#Assign 1,2,3 for low, medium and high values respectively in reg_pct_level column of dataset 
df['reg_pct_level'] = df['reg_pct_level'].map({'low': 1, 'medium': 2, 'high':3})

# %%
# Creating dummy variables from categorical columns:
newdf2 = pd.get_dummies(df, columns=['county_name'])
newdf2 = newdf2.drop(columns=['aggregation_name', 'membership_desc']) #dropping these two columns 
newdf2.head()  #second data frame for modeling
# Out:
#    nrc_code  nyc_ind  subgroup_code  enroll_cnt  grad_pct  dropout_pct  \
# 0         3        0              1         658      71.0         22.0
# 1         3        0              2         324      76.0         20.0
# 2         3        0              3         334      65.0         25.0
# 4         3        0              5         367      68.0         25.0
# 5         3        0              6          98      59.0         29.0
#
#    reg_pct_level  county_name_ALBANY  county_name_ALLEGANY  county_name_BRONX  \
# 0              2                   1                     0                  0
# 1              2                   1                     0                  0
# 2              2                   1                     0                  0
# 4              2                   1                     0                  0
# 5              2                   1                     0                  0
#
#    ...  county_name_SULLIVAN  county_name_TIOGA  county_name_TOMPKINS  \
# 0  ...                     0                  0                     0
# 1  ...                     0                  0                     0
# 2  ...                     0                  0                     0
# 4  ...                     0                  0                     0
# 5  ...                     0                  0                     0
#
#    county_name_ULSTER  county_name_WARREN  county_name_WASHINGTON  \
# 0                   0                   0                       0
# 1                   0                   0                       0
# 2                   0                   0                       0
# 4                   0                   0                       0
# 5                   0                   0                       0
#
#    county_name_WAYNE  county_name_WESTCHESTER  county_name_WYOMING  \
# 0                  0                        0                    0
# 1                  0                        0                    0
# 2                  0                        0                    0
# 4                  0                        0                    0
# 5                  0                        0                    0
#
#    county_name_YATES
# 0                  0
# 1                  0
# 2                  0
# 4                  0
# 5                  0
#
# [5 rows x 69 columns]

# %% [markdown]
# ### Decision Tree + Random Forest Modeling

# %%
from sklearn.model_selection import train_test_split
from category_encoders import OrdinalEncoder

# %% [markdown]
# #### Decision Tree

# %% [markdown]
# ##### model 1

# %%
X1 = newdf.drop(['reg_pct_level'], axis=1)

# %%
y1 = newdf['reg_pct_level']

# %%
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, y1, test_size = 0.33, random_state = 42)

# %%
encoder = OrdinalEncoder(cols=['enroll_cnt', 'grad_pct', 'dropout_pct', 'nrc_code', 'nyc_ind', 'subgroup_code'])
X_train1 = encoder.fit_transform(X_train1)

X_test1 = encoder.transform(X_test1)

# %%
from sklearn.tree import DecisionTreeClassifier
clf_en1 = DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=0)
clf_en1.fit(X_train1, y_train1)
y_pred_en1 = clf_en1.predict(X_test1)

# %%
# Calculate the absolute errors
errors4 = abs(y_pred_en1  - y_test1)
# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors4), 2))
# Out:
# Mean Absolute Error: 0.27

# %%
from sklearn.metrics import accuracy_score
print('Model accuracy score with criterion entropy: {0:0.4f}'. format(accuracy_score(y_test1, y_pred_en1)))
y_pred_train_en1 = clf_en1.predict(X_train1)
y_pred_train_en1
plt.figure(figsize=(12,8))
from sklearn import tree
tree.plot_tree(clf_en1.fit(X_train1, y_train1))
# Out:
# Model accuracy score with criterion entropy: 0.7393
# [Text(0.5, 0.875, 'x[3] <= 1.5\nentropy = 1.15\nsamples = 14530\nvalue = [3983, 9660, 887]'),
#  Text(0.25, 0.625, 'x[5] <= 1.5\nentropy = 1.118\nsamples = 1856\nvalue = [1175, 614, 67]'),
#  Text(0.125, 0.375, 'x[267] <= 0.5\nentropy = 0.939\nsamples = 163\nvalue = [21, 129, 13]'),
#  Text(0.0625, 0.125, 'entropy = 0.885\nsamples = 159\nvalue = [17, 129, 13]'),
#  Text(0.1875, 0.125, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0, 0]'),
#  Text(0.375, 0.375, 'x[24] <= 0.5\nentropy = 1.052\nsamples = 1693\nvalue = [1154, 485, 54]'),
#  Text(0.3125, 0.125, 'entropy = 1.013\nsamples = 1626\nvalue = [1149, 428, 49]'),
#  Text(0.4375, 0.125, 'entropy = 0.757\nsamples = 67\nvalue = [5, 57, 5]'),
#  Text(0.75, 0.625, 'x[5] <= 1.5\nentropy = 1.085\nsamples = 12674\nvalue = [2808, 9046, 820]'),
#  Text(0.625, 0.375, 'x[3] <= 3.5\nentropy = 1.113\nsamples = 1132\nvalue = [706, 390, 36]'),
#  Text(0.5625, 0.125, 'entropy = 1.19\nsamples = 890\nvalue = [488, 366, 36]'),
#  Text(0.6875, 0.125, 'entropy = 0.466\nsamples = 242\nvalue = [218, 24, 0]'),
#  Text(0.875, 0.375, 'x[5] <= 14.5\nentropy = 1.022\nsamples = 11542\nvalue = [2102, 8656, 784]'),
#  Text(0.8125, 0.125, 'entropy = 0.938\nsamples = 10467\nvalue = [1703, 8177, 587]'),
#  Text(0.9375, 0.125, 'entropy = 1.499\nsamples = 1075\nvalue = [399, 479, 197]')]

# %%
from sklearn.metrics import confusion_matrix
cm1 = confusion_matrix(y_test1, y_pred_en1)
cm1
# Out:
# array([[ 968, 1021,    0],
#        [ 441, 4323,    0],
#        [  40,  364,    0]])

# %% [markdown]
# ##### model 2

# %%
X2 = newdf2.drop(['reg_pct_level'], axis=1)

# %%
y2 = newdf2['reg_pct_level']

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2, test_size = 0.33, random_state = 42)

# %%
encoder = OrdinalEncoder(cols=['enroll_cnt', 'grad_pct', 'dropout_pct', 'nrc_code', 'nyc_ind', 'subgroup_code'])
X_train2 = encoder.fit_transform(X_train2)

X_test2 = encoder.transform(X_test2)

# %%
clf_en2 = DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=0)
clf_en2.fit(X_train2, y_train2)
y_pred_en2 = clf_en2.predict(X_test2)

# %%
# Calculate the absolute errors
errors3 = abs(y_pred_en2  - y_test2)
# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors3), 2))
# Out:
# Mean Absolute Error: 0.33

# %%
print('Model accuracy score with criterion entropy: {0:0.4f}'. format(accuracy_score(y_test2, y_pred_en2)))
y_pred_train_en2 = clf_en2.predict(X_train2)
y_pred_train_en2
plt.figure(figsize=(12,8))
from sklearn import tree
tree.plot_tree(clf_en2.fit(X_train2, y_train2))
# Out:
# Model accuracy score with criterion entropy: 0.6788
# [Text(0.5, 0.875, 'x[65] <= 0.5\nentropy = 1.199\nsamples = 26581\nvalue = [7113, 17375, 2093]'),
#  Text(0.25, 0.625, 'x[4] <= 64.5\nentropy = 1.121\nsamples = 24752\nvalue = [6797, 16650, 1305]'),
#  Text(0.125, 0.375, 'x[5] <= 2.5\nentropy = 1.107\nsamples = 24267\nvalue = [6343, 16619, 1305]'),
#  Text(0.0625, 0.125, 'entropy = 1.378\nsamples = 5408\nvalue = [1799, 2944, 665]'),
#  Text(0.1875, 0.125, 'entropy = 0.997\nsamples = 18859\nvalue = [4544, 13675, 640]'),
#  Text(0.375, 0.375, 'x[4] <= 79.5\nentropy = 0.343\nsamples = 485\nvalue = [454, 31, 0]'),
#  Text(0.3125, 0.125, 'entropy = 0.449\nsamples = 331\nvalue = [300, 31, 0]'),
#  Text(0.4375, 0.125, 'entropy = 0.0\nsamples = 154\nvalue = [154, 0, 0]'),
#  Text(0.75, 0.625, 'x[4] <= 39.5\nentropy = 1.49\nsamples = 1829\nvalue = [316, 725, 788]'),
#  Text(0.625, 0.375, 'x[0] <= 3.5\nentropy = 1.417\nsamples = 1652\nvalue = [210, 657, 785]'),
#  Text(0.5625, 0.125, 'entropy = 1.186\nsamples = 456\nvalue = [31, 295, 130]'),
#  Text(0.6875, 0.125, 'entropy = 1.408\nsamples = 1196\nvalue = [179, 362, 655]'),
#  Text(0.875, 0.375, 'x[4] <= 60.5\nentropy = 1.073\nsamples = 177\nvalue = [106, 68, 3]'),
#  Text(0.8125, 0.125, 'entropy = 1.125\nsamples = 117\nvalue = [47, 67, 3]'),
#  Text(0.9375, 0.125, 'entropy = 0.122\nsamples = 60\nvalue = [59, 1, 0]')]

# %%
cm2 = confusion_matrix(y_test2, y_pred_en2)
cm2
# Out:
# array([[ 273, 3207,   87],
#        [  16, 8319,  175],
#        [   0,  721,  295]])

# %% [markdown]
# #### Random Forest

# %% [markdown]
# ##### Model 1

# %%
feature_list1 = list(X1.columns) #for future use

# %%
# Import the model we are using
from sklearn.ensemble import RandomForestRegressor

# %%
# Instantiate model with 1000 decision trees
rf1 = RandomForestRegressor(n_estimators = 1000, random_state = 42)
# Train the model on training data
rf1.fit(X_train1, y_train1);

# %%
# Use the forest's predict method on the test data
predictions1 = rf1.predict(X_test1)
# Calculate the absolute errors
errors1 = abs(predictions1 - y_test1)
# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors1), 2))
# Out:
# Mean Absolute Error: 0.23

# %%
# Calculate mean absolute percentage error (MAPE)
mape1 = 100 * (errors1 / y_test1)
# Calculate and display accuracy
accuracy1 = 100 - np.mean(mape1)
print('Accuracy:', round(accuracy1, 2), '%')
# Out:
# Accuracy: 84.63 %

# %%
# Import tools needed for visualization
from sklearn.tree import export_graphviz
import pydot
# Pull out one tree from the forest
tre1 = rf1.estimators_[5]
# Export the image to a dot file
export_graphviz(tre1, out_file = 'tree.dot', feature_names = feature_list1, rounded = True, precision = 1)
# Use dot file to create a graph
(graph, ) = pydot.graph_from_dot_file('tree.dot')

# %%
text_representation1 = tree.export_text(tre1)
print(text_representation1)
# Out:
# |--- feature_3 <= 1.50
# |   |--- feature_5 <= 1.50
# |   |   |--- feature_294 <= 0.50
# |   |   |   |--- feature_37 <= 0.50
# |   |   |   |   |--- feature_267 <= 0.50
# |   |   |   |   |   |--- feature_388 <= 0.50
# |   |   |   |   |   |   |--- feature_291 <= 0.50
# |   |   |   |   |   |   |   |--- feature_95 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 52.50
# |   |   |   |   |   |   |   |   |   |--- feature_345 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_251 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- feature_251 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |   |--- feature_345 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 23.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  23.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |--- feature_1 >  52.50
# |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |--- feature_95 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_413 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 11.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  11.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |--- feature_413 >  0.50
# |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |--- feature_291 >  0.50
# |   |   |   |   |   |   |   |--- feature_411 <= 0.50
# |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |--- feature_411 >  0.50
# |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |--- feature_388 >  0.50
# |   |   |   |   |   |   |--- feature_2 <= 15.50
# |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |--- feature_2 >  15.50
# |   |   |   |   |   |   |   |--- feature_413 <= 0.50
# |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |--- feature_413 >  0.50
# |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |--- feature_267 >  0.50
# |   |   |   |   |   |--- value: [1.00]
# |   |   |   |--- feature_37 >  0.50
# |   |   |   |   |--- feature_414 <= 0.50
# |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |--- feature_414 >  0.50
# |   |   |   |   |   |--- value: [2.00]
# |   |   |--- feature_294 >  0.50
# |   |   |   |--- feature_2 <= 23.50
# |   |   |   |   |--- value: [3.00]
# |   |   |   |--- feature_2 >  23.50
# |   |   |   |   |--- value: [2.00]
# |   |--- feature_5 >  1.50
# |   |   |--- feature_5 <= 15.50
# |   |   |   |--- feature_404 <= 0.50
# |   |   |   |   |--- feature_202 <= 0.50
# |   |   |   |   |   |--- feature_402 <= 0.50
# |   |   |   |   |   |   |--- feature_5 <= 14.50
# |   |   |   |   |   |   |   |--- feature_5 <= 3.50
# |   |   |   |   |   |   |   |   |--- feature_264 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_389 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_413 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_413 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |--- feature_389 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |--- feature_264 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 7.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  7.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |--- feature_5 >  3.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 6.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 7.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 56.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  56.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  7.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- feature_5 >  6.50
# |   |   |   |   |   |   |   |   |   |--- feature_95 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_141 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- feature_141 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_95 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |--- feature_5 >  14.50
# |   |   |   |   |   |   |   |--- feature_264 <= 0.50
# |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |--- feature_264 >  0.50
# |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |--- feature_402 >  0.50
# |   |   |   |   |   |   |--- feature_415 <= 0.50
# |   |   |   |   |   |   |   |--- feature_5 <= 8.50
# |   |   |   |   |   |   |   |   |--- feature_414 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |--- feature_414 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 63.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 17.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  17.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  63.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |--- feature_5 >  8.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 10.00
# |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |--- feature_5 >  10.00
# |   |   |   |   |   |   |   |   |   |--- feature_416 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |   |--- feature_416 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 105.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  105.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |--- feature_415 >  0.50
# |   |   |   |   |   |   |   |--- feature_2 <= 11.00
# |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |--- feature_2 >  11.00
# |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |--- feature_202 >  0.50
# |   |   |   |   |   |--- feature_1 <= 19.50
# |   |   |   |   |   |   |--- feature_414 <= 0.50
# |   |   |   |   |   |   |   |--- feature_416 <= 0.50
# |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |--- feature_416 >  0.50
# |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |--- feature_414 >  0.50
# |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |--- feature_1 >  19.50
# |   |   |   |   |   |   |--- feature_1 <= 27.50
# |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |--- feature_1 >  27.50
# |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |--- feature_404 >  0.50
# |   |   |   |   |--- feature_24 <= 0.50
# |   |   |   |   |   |--- feature_308 <= 0.50
# |   |   |   |   |   |   |--- feature_54 <= 0.50
# |   |   |   |   |   |   |   |--- feature_5 <= 3.50
# |   |   |   |   |   |   |   |   |--- feature_267 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |--- feature_267 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_413 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |--- feature_413 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |--- feature_5 >  3.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 6.50
# |   |   |   |   |   |   |   |   |   |--- feature_340 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 23.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  23.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |--- feature_340 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |--- feature_5 >  6.50
# |   |   |   |   |   |   |   |   |   |--- feature_277 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_307 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- feature_307 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_277 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 12.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  12.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |--- feature_54 >  0.50
# |   |   |   |   |   |   |   |--- feature_412 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_411 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 5.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 6.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  6.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  5.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |--- feature_411 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 96.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  96.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |--- feature_412 >  0.50
# |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |--- feature_308 >  0.50
# |   |   |   |   |   |   |--- feature_5 <= 14.50
# |   |   |   |   |   |   |   |--- feature_5 <= 2.50
# |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |--- feature_5 >  2.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 117.00
# |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |--- feature_0 >  117.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 125.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  125.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |--- feature_5 >  14.50
# |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |--- feature_24 >  0.50
# |   |   |   |   |   |--- feature_5 <= 14.50
# |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |--- feature_5 >  14.50
# |   |   |   |   |   |   |--- feature_0 <= 50.00
# |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |--- feature_0 >  50.00
# |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |--- feature_5 >  15.50
# |   |   |   |--- feature_5 <= 16.50
# |   |   |   |   |--- feature_168 <= 0.50
# |   |   |   |   |   |--- feature_328 <= 0.50
# |   |   |   |   |   |   |--- feature_375 <= 0.50
# |   |   |   |   |   |   |   |--- feature_136 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_260 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_308 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |   |--- feature_308 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_415 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_415 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |--- feature_260 >  0.50
# |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |--- feature_136 >  0.50
# |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |--- feature_375 >  0.50
# |   |   |   |   |   |   |   |--- feature_1 <= 47.50
# |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |--- feature_1 >  47.50
# |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |--- feature_328 >  0.50
# |   |   |   |   |   |   |--- feature_2 <= 38.00
# |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |--- feature_2 >  38.00
# |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |--- feature_168 >  0.50
# |   |   |   |   |   |--- value: [1.00]
# |   |   |   |--- feature_5 >  16.50
# |   |   |   |   |--- feature_149 <= 0.50
# |   |   |   |   |   |--- feature_402 <= 0.50
# |   |   |   |   |   |   |--- feature_0 <= 254.00
# |   |   |   |   |   |   |   |--- feature_267 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 15.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 29.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_407 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- feature_407 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  29.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 12.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  12.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |--- feature_2 >  15.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 50.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 24.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  24.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  50.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |--- feature_267 >  0.50
# |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |--- feature_0 >  254.00
# |   |   |   |   |   |   |   |--- feature_415 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_32 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |--- feature_32 >  0.50
# |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |--- feature_415 >  0.50
# |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |--- feature_402 >  0.50
# |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |--- feature_149 >  0.50
# |   |   |   |   |   |--- feature_0 <= 385.00
# |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |--- feature_0 >  385.00
# |   |   |   |   |   |   |--- value: [2.00]
# |--- feature_3 >  1.50
# |   |--- feature_5 <= 1.50
# |   |   |--- feature_3 <= 3.50
# |   |   |   |--- feature_118 <= 0.50
# |   |   |   |   |--- feature_157 <= 0.50
# |   |   |   |   |   |--- feature_389 <= 0.50
# |   |   |   |   |   |   |--- feature_246 <= 0.50
# |   |   |   |   |   |   |   |--- feature_63 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_324 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_23 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_310 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 46
# |   |   |   |   |   |   |   |   |   |   |--- feature_310 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_23 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |--- feature_324 >  0.50
# |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |--- feature_63 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 276.50
# |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |--- feature_0 >  276.50
# |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |--- feature_246 >  0.50
# |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |--- feature_389 >  0.50
# |   |   |   |   |   |   |--- feature_68 <= 0.50
# |   |   |   |   |   |   |   |--- feature_249 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_142 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_414 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- feature_414 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- feature_142 >  0.50
# |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |--- feature_249 >  0.50
# |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |--- feature_68 >  0.50
# |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |--- feature_157 >  0.50
# |   |   |   |   |   |--- feature_2 <= 5.50
# |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |--- feature_2 >  5.50
# |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |--- feature_118 >  0.50
# |   |   |   |   |--- value: [3.00]
# |   |   |--- feature_3 >  3.50
# |   |   |   |--- feature_235 <= 0.50
# |   |   |   |   |--- feature_213 <= 0.50
# |   |   |   |   |   |--- feature_169 <= 0.50
# |   |   |   |   |   |   |--- feature_239 <= 0.50
# |   |   |   |   |   |   |   |--- feature_0 <= 3.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 1.50
# |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |--- feature_0 >  1.50
# |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |--- feature_0 >  3.00
# |   |   |   |   |   |   |   |   |--- feature_225 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_237 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |   |--- feature_237 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |--- feature_225 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 12.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  12.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |--- feature_239 >  0.50
# |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |--- feature_169 >  0.50
# |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |--- feature_213 >  0.50
# |   |   |   |   |   |--- value: [2.00]
# |   |   |   |--- feature_235 >  0.50
# |   |   |   |   |--- value: [2.00]
# |   |--- feature_5 >  1.50
# |   |   |--- feature_402 <= 0.50
# |   |   |   |--- feature_5 <= 16.50
# |   |   |   |   |--- feature_5 <= 15.50
# |   |   |   |   |   |--- feature_3 <= 2.50
# |   |   |   |   |   |   |--- feature_39 <= 0.50
# |   |   |   |   |   |   |   |--- feature_52 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_31 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_153 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_93 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 34
# |   |   |   |   |   |   |   |   |   |   |--- feature_93 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_153 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 22.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  22.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |--- feature_31 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_412 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_411 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_411 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |--- feature_412 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 6.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  6.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |--- feature_52 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 18.00
# |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |--- feature_2 >  18.00
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 28.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  28.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |--- feature_39 >  0.50
# |   |   |   |   |   |   |   |--- feature_416 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_415 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |--- feature_415 >  0.50
# |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |--- feature_416 >  0.50
# |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |--- feature_3 >  2.50
# |   |   |   |   |   |   |--- feature_3 <= 3.50
# |   |   |   |   |   |   |   |--- feature_5 <= 14.50
# |   |   |   |   |   |   |   |   |--- feature_8 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_72 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_180 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 75
# |   |   |   |   |   |   |   |   |   |   |--- feature_180 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |   |--- feature_72 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 411.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  411.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_8 >  0.50
# |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |--- feature_5 >  14.50
# |   |   |   |   |   |   |   |   |--- feature_182 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_99 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 44.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  44.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |--- feature_99 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |--- feature_182 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 28.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  28.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |--- feature_3 >  3.50
# |   |   |   |   |   |   |   |--- feature_228 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_106 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 4.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_229 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- feature_229 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  4.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 8.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 20
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  8.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 27
# |   |   |   |   |   |   |   |   |--- feature_106 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_415 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_416 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_416 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_415 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |--- feature_228 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 14.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 4.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 8.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  8.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  4.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_413 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_413 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_5 >  14.50
# |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |--- feature_5 >  15.50
# |   |   |   |   |   |--- feature_147 <= 0.50
# |   |   |   |   |   |   |--- feature_0 <= 147.00
# |   |   |   |   |   |   |   |--- feature_237 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 50.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_409 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_409 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_236 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_236 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |--- feature_0 >  50.50
# |   |   |   |   |   |   |   |   |   |--- feature_409 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 55.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  55.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |--- feature_409 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |--- feature_237 >  0.50
# |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |--- feature_0 >  147.00
# |   |   |   |   |   |   |   |--- feature_0 <= 306.50
# |   |   |   |   |   |   |   |   |--- feature_227 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_389 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_166 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- feature_166 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |   |--- feature_389 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_411 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_411 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |--- feature_227 >  0.50
# |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |--- feature_0 >  306.50
# |   |   |   |   |   |   |   |   |--- feature_151 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_213 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_410 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_410 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |--- feature_213 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |--- feature_151 >  0.50
# |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |--- feature_147 >  0.50
# |   |   |   |   |   |   |--- feature_0 <= 108.00
# |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |--- feature_0 >  108.00
# |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |--- feature_5 >  16.50
# |   |   |   |   |--- feature_5 <= 18.50
# |   |   |   |   |   |--- feature_408 <= 0.50
# |   |   |   |   |   |   |--- feature_327 <= 0.50
# |   |   |   |   |   |   |   |--- feature_173 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_235 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_224 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_220 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |   |--- feature_220 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |--- feature_224 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |--- feature_235 >  0.50
# |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |--- feature_173 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_415 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |--- feature_415 >  0.50
# |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |--- feature_327 >  0.50
# |   |   |   |   |   |   |   |--- feature_1 <= 34.00
# |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |--- feature_1 >  34.00
# |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |--- feature_408 >  0.50
# |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |--- feature_5 >  18.50
# |   |   |   |   |   |--- feature_4 <= 1.50
# |   |   |   |   |   |   |--- feature_163 <= 0.50
# |   |   |   |   |   |   |   |--- feature_368 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_71 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 783.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_185 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |   |--- feature_185 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  783.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 45.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  45.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |--- feature_71 >  0.50
# |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |--- feature_368 >  0.50
# |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |--- feature_163 >  0.50
# |   |   |   |   |   |   |   |--- feature_411 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_412 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |--- feature_412 >  0.50
# |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |--- feature_411 >  0.50
# |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |--- feature_4 >  1.50
# |   |   |   |   |   |   |--- feature_0 <= 199.00
# |   |   |   |   |   |   |   |--- feature_0 <= 31.00
# |   |   |   |   |   |   |   |   |--- feature_1 <= 9.00
# |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |--- feature_1 >  9.00
# |   |   |   |   |   |   |   |   |   |--- feature_217 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_237 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_237 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |   |--- feature_217 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |--- feature_0 >  31.00
# |   |   |   |   |   |   |   |   |--- feature_2 <= 2.50
# |   |   |   |   |   |   |   |   |   |--- feature_212 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |--- feature_212 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |--- feature_2 >  2.50
# |   |   |   |   |   |   |   |   |   |--- feature_230 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_238 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- feature_238 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |--- feature_230 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 19.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  19.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |--- feature_0 >  199.00
# |   |   |   |   |   |   |   |--- feature_224 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_212 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_220 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_232 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_232 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |   |--- feature_220 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |--- feature_212 >  0.50
# |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |--- feature_224 >  0.50
# |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |--- feature_402 >  0.50
# |   |   |   |--- feature_3 <= 4.50
# |   |   |   |   |--- feature_137 <= 0.50
# |   |   |   |   |   |--- feature_98 <= 0.50
# |   |   |   |   |   |   |--- feature_96 <= 0.50
# |   |   |   |   |   |   |   |--- feature_364 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 3.50
# |   |   |   |   |   |   |   |   |   |--- feature_126 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 790.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  790.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |--- feature_126 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |--- feature_5 >  3.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 6.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  6.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 8.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  8.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |--- feature_364 >  0.50
# |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |--- feature_96 >  0.50
# |   |   |   |   |   |   |   |--- feature_411 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 7.00
# |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |--- feature_0 >  7.00
# |   |   |   |   |   |   |   |   |   |--- feature_412 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 43.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  43.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- feature_412 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 28.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  28.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |--- feature_411 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 13.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 19.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  19.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 37.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  37.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_5 >  13.50
# |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |--- feature_98 >  0.50
# |   |   |   |   |   |   |--- feature_1 <= 40.00
# |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |--- feature_1 >  40.00
# |   |   |   |   |   |   |   |--- feature_2 <= 4.00
# |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |--- feature_2 >  4.00
# |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |--- feature_137 >  0.50
# |   |   |   |   |   |--- feature_5 <= 14.50
# |   |   |   |   |   |   |--- feature_2 <= 1.50
# |   |   |   |   |   |   |   |--- feature_1 <= 31.50
# |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |--- feature_1 >  31.50
# |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |--- feature_2 >  1.50
# |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |--- feature_5 >  14.50
# |   |   |   |   |   |   |--- feature_5 <= 15.50
# |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |--- feature_5 >  15.50
# |   |   |   |   |   |   |   |--- feature_413 <= 0.50
# |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |--- feature_413 >  0.50
# |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |--- feature_3 >  4.50
# |   |   |   |   |--- feature_0 <= 186.50
# |   |   |   |   |   |--- feature_5 <= 16.50
# |   |   |   |   |   |   |--- feature_5 <= 15.50
# |   |   |   |   |   |   |   |--- feature_414 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 11.00
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 8.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  8.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |--- feature_1 >  11.00
# |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |--- feature_414 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 66.00
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 18.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  18.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |--- feature_0 >  66.00
# |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |--- feature_5 >  15.50
# |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |--- feature_5 >  16.50
# |   |   |   |   |   |   |--- feature_5 <= 19.00
# |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |--- feature_5 >  19.00
# |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |--- feature_0 >  186.50
# |   |   |   |   |   |--- feature_1 <= 5.50
# |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |--- feature_1 >  5.50
# |   |   |   |   |   |   |--- value: [3.00]

# %%
# Get numerical feature importances
importances = list(rf.feature_importances_)
# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]
# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: subgroup_code        Importance: 0.22
# Variable: nrc_code             Importance: 0.1
# Variable: enroll_cnt           Importance: 0.07
# Variable: grad_pct             Importance: 0.06
# Variable: dropout_pct          Importance: 0.05
# Variable: county_name_MONROE   Importance: 0.03
# Variable: membership_desc_2013 Total Cohort - 6 Year Outcome Importance: 0.02
# Variable: membership_desc_2015 Total Cohort - 4 Year Outcome Importance: 0.02
# Variable: nyc_ind              Importance: 0.01
# Variable: aggregation_name_BALDWIN UNION FREE SCHOOL DISTRICT Importance: 0.01
# Variable: aggregation_name_JAMESVILLE-DEWITT CENTRAL SCHOOL DISTRICT Importance: 0.01
# Variable: aggregation_name_MILLBROOK CENTRAL SCHOOL DISTRICT Importance: 0.01
# Variable: county_name_NASSAU   Importance: 0.01
# Variable: membership_desc_2013 Total Cohort - 6 Year Outcome - August 2019 Importance: 0.01
# Variable: membership_desc_2014 Total Cohort - 5 Year Outcome Importance: 0.01
# Variable: membership_desc_2014 Total Cohort - 5 Year Outcome - August 2019 Importance: 0.01
# Variable: membership_desc_2015 Total Cohort - 4 Year Outcome - August 2019 Importance: 0.01
# Variable: aggregation_name_ADIRONDACK CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_AFTON CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_AKRON CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_ALBANY CITY SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_ALDEN CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_ALEXANDER CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_ALEXANDRIA CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_ALFRED-ALMOND CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_ALLEGANY-LIMESTONE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_AMHERST CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_AMSTERDAM CITY SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_ANDES CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_ANDOVER CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_ARLINGTON CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_AUBURN CITY SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_AUSABLE VALLEY CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_AVON CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_BAINBRIDGE-GUILFORD CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_BARKER CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_BATAVIA CITY SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_BEACON CITY SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_BEAVER RIVER CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_BEEKMANTOWN CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_BELFAST CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_BELLEVILLE-HENDERSON CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_BELLMORE-MERRICK CENTRAL HIGH SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_BEMUS POINT CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_BERKSHIRE UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_BERNE-KNOX-WESTERLO CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_BETHLEHEM CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_BETHPAGE UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_BINGHAMTON CITY SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_BOLIVAR-RICHBURG CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_BRIGHTON CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_BROADALBIN-PERTH CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_BROCKPORT CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_BROCTON CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_BROOKFIELD CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_BRUSHTON-MOIRA CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_BUFFALO CITY SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_BYRON-BERGEN CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_CAIRO-DURHAM CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_CALEDONIA-MUMFORD CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_CAMDEN CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_CANAJOHARIE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_CANASERAGA CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_CANASTOTA CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_CARLE PLACE UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_CARTHAGE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_CASSADAGA VALLEY CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_CATO-MERIDIAN CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_CATSKILL CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_CATTARAUGUS-LITTLE VALLEY CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_CAZENOVIA CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_CENTRAL VALLEY CSD AT ILION-MOHAWK Importance: 0.0
# Variable: aggregation_name_CHARLOTTE VALLEY CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_CHATEAUGAY CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_CHATHAM CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_CHAUTAUQUA LAKE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_CHAZY UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_CHEEKTOWAGA CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_CHEEKTOWAGA-MARYVALE UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_CHEEKTOWAGA-SLOAN UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_CHENANGO FORKS CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_CHENANGO VALLEY CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_CHITTENANGO CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_CHURCHVILLE-CHILI CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_CINCINNATUS CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_CLARENCE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_CLEVELAND HILL UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_CLINTON CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_CLYMER CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_COHOES CITY SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_COPENHAGEN CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_CORTLAND CITY SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_COXSACKIE-ATHENS CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_CROWN POINT CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_CUBA-RUSHFORD CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_DALTON-NUNDA CENTRAL SCHOOL DISTRICT (KESHEQUA) Importance: 0.0
# Variable: aggregation_name_DANSVILLE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_DELAWARE ACADEMY CENTRAL SCHOOL DISTRICT AT DELHI Importance: 0.0
# Variable: aggregation_name_DEPEW UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_DEPOSIT CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_DERUYTER CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_DOLGEVILLE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_DOVER UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_DOWNSVILLE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_DUNKIRK CITY SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_EAST AURORA UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_EAST IRONDEQUOIT CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_EAST MEADOW UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_EAST ROCHESTER UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_EAST ROCKAWAY UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_EAST SYRACUSE MINOA CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_EAST WILLISTON UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_EDEN CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_ELBA CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_ELIZABETHTOWN-LEWIS CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_ELLICOTTVILLE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_ELMIRA CITY SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_ELMIRA HEIGHTS CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_EVANS-BRANT CENTRAL SCHOOL DISTRICT (LAKE SHORE) Importance: 0.0
# Variable: aggregation_name_FABIUS-POMPEY CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_FAIRPORT CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_FALCONER CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_FARMINGDALE UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_FILLMORE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_FONDA-FULTONVILLE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_FORESTVILLE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_FORT PLAIN CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_FRANKFORT-SCHUYLER CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_FRANKLIN CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_FRANKLINVILLE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_FREDONIA CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_FREEPORT UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_FREWSBURG CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_FRIENDSHIP CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_FRONTIER CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_GARDEN CITY UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_GATES-CHILI CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_GENERAL BROWN CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_GENESEE VALLEY CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_GENESEO CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_GEORGETOWN-SOUTH OTSELIC CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_GERMANTOWN CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_GLEN COVE CITY SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_GLOVERSVILLE CITY SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_GOWANDA CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_GRAND ISLAND CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_GREAT NECK UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_GREECE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_GREEN ISLAND UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_GREENE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_GREENVILLE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_GUILDERLAND CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_HAMBURG CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_HAMILTON CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_HANCOCK CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_HARPURSVILLE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_HARRISVILLE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_HEMPSTEAD UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_HERKIMER CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_HERRICKS UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_HEWLETT-WOODMERE UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_HICKSVILLE UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_HILTON CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_HINSDALE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_HOLLAND CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_HOLLAND PATENT CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_HOMER CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_HONEOYE FALLS-LIMA CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_HORSEHEADS CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_HUDSON CITY SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_HUNTER-TANNERSVILLE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_HYDE PARK CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_INDIAN LAKE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_INDIAN RIVER CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_IROQUOIS CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_ISLAND TREES UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_JAMESTOWN CITY SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_JERICHO UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_JOHNSON CITY CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_JOHNSTOWN CITY SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_JORDAN-ELBRIDGE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_KEENE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_KENMORE-TONAWANDA UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_KINDERHOOK CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_LA FARGEVILLE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_LACKAWANNA CITY SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_LAKE PLACID CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_LANCASTER CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_LAWRENCE UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_LE ROY CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_LEVITTOWN UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_LEWISTON-PORTER CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_LITTLE FALLS CITY SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_LIVONIA CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_LOCKPORT CITY SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_LOCUST VALLEY CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_LONG BEACH CITY SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_LONG LAKE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_LOWVILLE ACADEMY & CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_LYME CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_LYNBROOK UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_MADISON CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_MAINE-ENDWELL CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_MALONE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_MALVERNE UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_MANHASSET UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_MARATHON CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_MARGARETVILLE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_MASSAPEQUA UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_MAYFIELD CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_MCGRAW CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_MINEOLA UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_MINERVA CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_MORAVIA CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_MORIAH CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_MORRISVILLE-EATON CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_MOUNT MARKHAM CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_MOUNT MORRIS CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_NEW HARTFORD CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_NEW LEBANON CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_NEW YORK CITY GEOGRAPHIC DISTRICT # 1 Importance: 0.0
# Variable: aggregation_name_NEW YORK CITY GEOGRAPHIC DISTRICT # 2 Importance: 0.0
# Variable: aggregation_name_NEW YORK CITY GEOGRAPHIC DISTRICT # 3 Importance: 0.0
# Variable: aggregation_name_NEW YORK CITY GEOGRAPHIC DISTRICT # 4 Importance: 0.0
# Variable: aggregation_name_NEW YORK CITY GEOGRAPHIC DISTRICT # 5 Importance: 0.0
# Variable: aggregation_name_NEW YORK CITY GEOGRAPHIC DISTRICT # 6 Importance: 0.0
# Variable: aggregation_name_NEW YORK CITY GEOGRAPHIC DISTRICT # 7 Importance: 0.0
# Variable: aggregation_name_NEW YORK CITY GEOGRAPHIC DISTRICT # 8 Importance: 0.0
# Variable: aggregation_name_NEW YORK CITY GEOGRAPHIC DISTRICT # 9 Importance: 0.0
# Variable: aggregation_name_NEW YORK CITY GEOGRAPHIC DISTRICT #10 Importance: 0.0
# Variable: aggregation_name_NEW YORK CITY GEOGRAPHIC DISTRICT #11 Importance: 0.0
# Variable: aggregation_name_NEW YORK CITY GEOGRAPHIC DISTRICT #12 Importance: 0.0
# Variable: aggregation_name_NEW YORK CITY GEOGRAPHIC DISTRICT #13 Importance: 0.0
# Variable: aggregation_name_NEW YORK CITY GEOGRAPHIC DISTRICT #14 Importance: 0.0
# Variable: aggregation_name_NEW YORK CITY GEOGRAPHIC DISTRICT #15 Importance: 0.0
# Variable: aggregation_name_NEW YORK CITY GEOGRAPHIC DISTRICT #16 Importance: 0.0
# Variable: aggregation_name_NEW YORK CITY GEOGRAPHIC DISTRICT #17 Importance: 0.0
# Variable: aggregation_name_NEW YORK CITY GEOGRAPHIC DISTRICT #18 Importance: 0.0
# Variable: aggregation_name_NEW YORK CITY GEOGRAPHIC DISTRICT #19 Importance: 0.0
# Variable: aggregation_name_NEW YORK CITY GEOGRAPHIC DISTRICT #20 Importance: 0.0
# Variable: aggregation_name_NEW YORK CITY GEOGRAPHIC DISTRICT #21 Importance: 0.0
# Variable: aggregation_name_NEW YORK CITY GEOGRAPHIC DISTRICT #22 Importance: 0.0
# Variable: aggregation_name_NEW YORK CITY GEOGRAPHIC DISTRICT #23 Importance: 0.0
# Variable: aggregation_name_NEW YORK CITY GEOGRAPHIC DISTRICT #24 Importance: 0.0
# Variable: aggregation_name_NEW YORK CITY GEOGRAPHIC DISTRICT #25 Importance: 0.0
# Variable: aggregation_name_NEW YORK CITY GEOGRAPHIC DISTRICT #26 Importance: 0.0
# Variable: aggregation_name_NEW YORK CITY GEOGRAPHIC DISTRICT #27 Importance: 0.0
# Variable: aggregation_name_NEW YORK CITY GEOGRAPHIC DISTRICT #28 Importance: 0.0
# Variable: aggregation_name_NEW YORK CITY GEOGRAPHIC DISTRICT #29 Importance: 0.0
# Variable: aggregation_name_NEW YORK CITY GEOGRAPHIC DISTRICT #30 Importance: 0.0
# Variable: aggregation_name_NEW YORK CITY GEOGRAPHIC DISTRICT #31 Importance: 0.0
# Variable: aggregation_name_NEW YORK CITY GEOGRAPHIC DISTRICT #32 Importance: 0.0
# Variable: aggregation_name_NEW YORK MILLS UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_NEWCOMB CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_NEWFANE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_NIAGARA FALLS CITY SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_NIAGARA-WHEATFIELD CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_NORTH COLLINS CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_NORTH COLONIE CSD Importance: 0.0
# Variable: aggregation_name_NORTH SHORE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_NORTH SYRACUSE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_NORTH TONAWANDA CITY SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_NORTHEAST CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_NORTHEASTERN CLINTON CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_NORTHERN ADIRONDACK CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_NORTHVILLE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_NORWICH CITY SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_OAKFIELD-ALABAMA CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_OCEANSIDE UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_OLEAN CITY SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_ONEIDA CITY SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_OPPENHEIM-EPHRATAH-ST. JOHNSVILLE CSD Importance: 0.0
# Variable: aggregation_name_ORCHARD PARK CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_ORISKANY CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_OXFORD ACADEMY AND CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_OYSTER BAY-EAST NORWICH CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_PANAMA CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_PAVILION CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_PAWLING CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_PEMBROKE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_PENFIELD CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_PERU CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_PINE PLAINS CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_PINE VALLEY CENTRAL SCHOOL DISTRICT (SOUTH DAYTON) Importance: 0.0
# Variable: aggregation_name_PITTSFORD CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_PLAINEDGE UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_PLAINVIEW-OLD BETHPAGE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_PLATTSBURGH CITY SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_POLAND CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_PORT BYRON CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_PORT WASHINGTON UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_PORTVILLE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_POUGHKEEPSIE CITY SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_RANDOLPH CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_RAVENA-COEYMANS-SELKIRK CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_RED HOOK CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_REMSEN CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_RHINEBECK CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_ROCHESTER CITY SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_ROCKVILLE CENTRE UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_ROME CITY SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_ROOSEVELT UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_ROSLYN UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_ROXBURY CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_ROYALTON-HARTLAND CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_RUSH-HENRIETTA CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_SACKETS HARBOR CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_SAINT REGIS FALLS CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_SALAMANCA CITY SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_SALMON RIVER CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_SARANAC CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_SARANAC LAKE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_SAUQUOIT VALLEY CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_SCHROON LAKE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_SCIO CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_SEAFORD UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_SEWANHAKA CENTRAL HIGH SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_SHERBURNE-EARLVILLE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_SHERMAN CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_SHERRILL CITY SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_SIDNEY CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_SILVER CREEK CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_SOUTH COLONIE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_SOUTH JEFFERSON CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_SOUTH KORTRIGHT CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_SOUTH LEWIS CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_SOUTHERN CAYUGA CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_SOUTHWESTERN CENTRAL SCHOOL DISTRICT AT JAMESTOWN Importance: 0.0
# Variable: aggregation_name_SPACKENKILL UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_SPENCERPORT CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_SPRINGVILLE-GRIFFITH INSTITUTE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_STAMFORD CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_STARPOINT CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_STOCKBRIDGE VALLEY CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_SUSQUEHANNA VALLEY CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_SWEET HOME CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_SYOSSET CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_TACONIC HILLS CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_THOUSAND ISLANDS CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_TICONDEROGA CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_TONAWANDA CITY SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_TOWN OF WEBB UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_TUPPER LAKE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_UNADILLA VALLEY CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_UNION SPRINGS CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_UNION-ENDICOTT CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_UNIONDALE UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_UTICA CITY SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_VALLEY STREAM CENTRAL HIGH SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_VAN HORNESVILLE-OWEN D YOUNG CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_VESTAL CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_VOORHEESVILLE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_WALTON CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_WANTAGH UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_WAPPINGERS CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_WATERTOWN CITY SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_WATERVILLE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_WATERVLIET CITY SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_WEBSTER CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_WEEDSPORT CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_WELLS CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_WELLSVILLE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_WEST CANADA VALLEY CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_WEST GENESEE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_WEST HEMPSTEAD UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_WEST IRONDEQUOIT CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_WEST SENECA CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_WEST VALLEY CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_WESTBURY UNION FREE SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_WESTFIELD CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_WESTMORELAND CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_WESTPORT CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_WHEATLAND-CHILI CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_WHITESBORO CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_WHITESVILLE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_WHITNEY POINT CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_WILLIAMSVILLE CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_WILLSBORO CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_WILSON CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_WINDHAM-ASHLAND-JEWETT CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_WINDSOR CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_YORK CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: aggregation_name_YORKSHIRE-PIONEER CENTRAL SCHOOL DISTRICT Importance: 0.0
# Variable: county_name_ALBANY   Importance: 0.0
# Variable: county_name_ALLEGANY Importance: 0.0
# Variable: county_name_BRONX    Importance: 0.0
# Variable: county_name_BROOME   Importance: 0.0
# Variable: county_name_CATTARAUGUS Importance: 0.0
# Variable: county_name_CAYUGA   Importance: 0.0
# Variable: county_name_CHAUTAUQUA Importance: 0.0
# Variable: county_name_CHEMUNG  Importance: 0.0
# Variable: county_name_CHENANGO Importance: 0.0
# Variable: county_name_CLINTON  Importance: 0.0
# Variable: county_name_COLUMBIA Importance: 0.0
# Variable: county_name_CORTLAND Importance: 0.0
# Variable: county_name_DELAWARE Importance: 0.0
# Variable: county_name_DUTCHESS Importance: 0.0
# Variable: county_name_ERIE     Importance: 0.0
# Variable: county_name_ESSEX    Importance: 0.0
# Variable: county_name_FRANKLIN Importance: 0.0
# Variable: county_name_FULTON   Importance: 0.0
# Variable: county_name_GENESEE  Importance: 0.0
# Variable: county_name_GREENE   Importance: 0.0
# Variable: county_name_HAMILTON Importance: 0.0
# Variable: county_name_HERKIMER Importance: 0.0
# Variable: county_name_JEFFERSON Importance: 0.0
# Variable: county_name_KINGS    Importance: 0.0
# Variable: county_name_LEWIS    Importance: 0.0
# Variable: county_name_LIVINGSTON Importance: 0.0
# Variable: county_name_MADISON  Importance: 0.0
# Variable: county_name_MONTGOMERY Importance: 0.0
# Variable: county_name_NEW YORK Importance: 0.0
# Variable: county_name_NIAGARA  Importance: 0.0
# Variable: county_name_ONEIDA   Importance: 0.0
# Variable: county_name_ONONDAGA Importance: 0.0
# Variable: county_name_QUEENS   Importance: 0.0
# Variable: county_name_RICHMOND Importance: 0.0

# %% [markdown]
# We can observe that "subgroup_code" , "nrc_code" has the highest importance compared to other variables in our training dataset

# %% [markdown]
# ##### Model 2

# %%
feature_list2 = list(X2.columns) #for future use

# %%
# Instantiate model with 1000 decision trees
rf2 = RandomForestRegressor(n_estimators = 1000, random_state = 42)
# Train the model on training data
rf2.fit(X_train2, y_train2);

# %%
# Use the forest's predict method on the test data
predictions2 = rf2.predict(X_test2)
# Calculate the absolute errors
errors2 = abs(predictions2 - y_test2)
# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors2), 2))
# Out:
# Mean Absolute Error: 0.2

# %%
# Calculate mean absolute percentage error (MAPE)
mape2 = 100 * (errors2 / y_test2)
# Calculate and display accuracy
accuracy2 = 100 - np.mean(mape2)
print('Accuracy:', round(accuracy2, 2), '%')
# Out:
# Accuracy: 86.61 %

# %%
# Pull out one tree from the forest
tre2 = rf2.estimators_[5]
# Export the image to a dot file
export_graphviz(tre2, out_file = 'tree2.dot', feature_names = feature_list2, rounded = True, precision = 1)
# Use dot file to create a graph
(graph, ) = pydot.graph_from_dot_file('tree2.dot')

# %%
text_representation2 = tree.export_text(tre2)
print(text_representation2)
# Out:
# |--- feature_65 <= 0.50
# |   |--- feature_4 <= 64.50
# |   |   |--- feature_35 <= 0.50
# |   |   |   |--- feature_2 <= 2.50
# |   |   |   |   |--- feature_2 <= 1.50
# |   |   |   |   |   |--- feature_57 <= 0.50
# |   |   |   |   |   |   |--- feature_33 <= 0.50
# |   |   |   |   |   |   |   |--- feature_0 <= 2.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 1.50
# |   |   |   |   |   |   |   |   |   |--- feature_28 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_44 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_44 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |   |--- feature_28 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |--- feature_4 >  1.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 24.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 6.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  6.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  24.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_31 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- feature_31 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |--- feature_0 >  2.50
# |   |   |   |   |   |   |   |   |--- feature_21 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_32 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_64 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 37
# |   |   |   |   |   |   |   |   |   |   |--- feature_64 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_32 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 39.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  39.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- feature_21 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 61.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  61.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 12.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  12.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- feature_33 >  0.50
# |   |   |   |   |   |   |   |--- feature_3 <= 266.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 10.50
# |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |--- feature_5 >  10.50
# |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |--- feature_3 >  266.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 907.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 688.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  688.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 10.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  10.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |--- feature_3 >  907.50
# |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |--- feature_57 >  0.50
# |   |   |   |   |   |   |--- feature_0 <= 3.50
# |   |   |   |   |   |   |   |--- feature_4 <= 15.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 684.00
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 9.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  9.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |--- feature_3 >  684.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 2.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  2.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |--- feature_4 >  15.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 10.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 8.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  8.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 27.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  27.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_5 >  10.50
# |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |--- feature_0 >  3.50
# |   |   |   |   |   |   |   |--- feature_3 <= 64.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 22.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 11.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 5.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  5.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  11.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |--- feature_4 >  22.50
# |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |--- feature_3 >  64.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 12.00
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 18.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 396.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  396.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  18.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 20.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  20.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- feature_5 >  12.00
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 567.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  567.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |--- feature_2 >  1.50
# |   |   |   |   |   |--- feature_5 <= 15.50
# |   |   |   |   |   |   |--- feature_4 <= 33.50
# |   |   |   |   |   |   |   |--- feature_57 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_38 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_53 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 24
# |   |   |   |   |   |   |   |   |   |   |--- feature_53 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |--- feature_38 >  0.50
# |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |--- feature_57 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 2.00
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 106.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  106.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |--- feature_0 >  2.00
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 52.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 41.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  41.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  52.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 75.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  75.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |--- feature_4 >  33.50
# |   |   |   |   |   |   |   |--- feature_49 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 38.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 26.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  26.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_39 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_39 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |--- feature_4 >  38.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 45.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 12.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  12.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  45.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_17 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 15
# |   |   |   |   |   |   |   |   |   |   |--- feature_17 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |--- feature_49 >  0.50
# |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |--- feature_5 >  15.50
# |   |   |   |   |   |   |--- feature_4 <= 27.50
# |   |   |   |   |   |   |   |--- feature_5 <= 34.50
# |   |   |   |   |   |   |   |   |--- feature_7 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_20 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 68.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 18
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  68.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |   |   |--- feature_20 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |--- feature_7 >  0.50
# |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |--- feature_5 >  34.50
# |   |   |   |   |   |   |   |   |--- feature_34 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_15 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |   |--- feature_15 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 87.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  87.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |--- feature_34 >  0.50
# |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |--- feature_4 >  27.50
# |   |   |   |   |   |   |   |--- feature_63 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_14 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 27.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 61.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 23
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  61.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  27.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_43 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |   |   |   |--- feature_43 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_14 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 39.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 89.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  89.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  39.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |--- feature_63 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 34.50
# |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |--- feature_3 >  34.50
# |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |--- feature_2 >  2.50
# |   |   |   |   |--- feature_0 <= 2.50
# |   |   |   |   |   |--- feature_4 <= 24.50
# |   |   |   |   |   |   |--- feature_5 <= 2.50
# |   |   |   |   |   |   |   |--- feature_4 <= 5.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 42.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 37.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  37.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_39 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_39 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |--- feature_3 >  42.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_44 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_44 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 13.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 20
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  13.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |--- feature_4 >  5.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 10.50
# |   |   |   |   |   |   |   |   |   |--- feature_44 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_30 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 23
# |   |   |   |   |   |   |   |   |   |   |--- feature_30 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_44 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 54.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  54.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_2 >  10.50
# |   |   |   |   |   |   |   |   |   |--- feature_47 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_34 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- feature_34 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |   |--- feature_47 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 13.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  13.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |--- feature_5 >  2.50
# |   |   |   |   |   |   |   |--- feature_57 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 10.50
# |   |   |   |   |   |   |   |   |   |--- feature_53 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 9.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 19
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  9.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |--- feature_53 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |--- feature_2 >  10.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 13.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 28.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  28.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  13.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 17.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  17.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |--- feature_57 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 13.00
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 1147.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 14.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  14.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  1147.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |--- feature_2 >  13.00
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 21.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 2.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  2.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  21.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 18.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  18.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |--- feature_4 >  24.50
# |   |   |   |   |   |   |--- feature_2 <= 10.50
# |   |   |   |   |   |   |   |--- feature_28 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 38.50
# |   |   |   |   |   |   |   |   |   |--- feature_32 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_30 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 20
# |   |   |   |   |   |   |   |   |   |   |--- feature_30 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_32 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 41.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  41.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- feature_5 >  38.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 100.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  100.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |--- feature_28 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 126.50
# |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |--- feature_3 >  126.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 26.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  26.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |--- feature_2 >  10.50
# |   |   |   |   |   |   |   |--- feature_4 <= 45.50
# |   |   |   |   |   |   |   |   |--- feature_37 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_31 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_19 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 17
# |   |   |   |   |   |   |   |   |   |   |--- feature_19 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |   |--- feature_31 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |--- feature_37 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 40.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 29.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  29.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  40.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |--- feature_4 >  45.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 51.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 49.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 47.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  47.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  49.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |--- feature_4 >  51.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 11.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 3.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  3.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  11.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |--- feature_0 >  2.50
# |   |   |   |   |   |--- feature_0 <= 4.50
# |   |   |   |   |   |   |--- feature_0 <= 3.50
# |   |   |   |   |   |   |   |--- feature_2 <= 10.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 9.50
# |   |   |   |   |   |   |   |   |   |--- feature_33 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 8.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 35
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  8.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 26
# |   |   |   |   |   |   |   |   |   |--- feature_33 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 146.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  146.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |--- feature_2 >  9.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 21.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 24
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  21.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_10 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 19
# |   |   |   |   |   |   |   |   |   |   |--- feature_10 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |--- feature_2 >  10.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 13.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 12.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_33 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 35
# |   |   |   |   |   |   |   |   |   |   |--- feature_33 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  12.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_20 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 18
# |   |   |   |   |   |   |   |   |   |   |--- feature_20 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |--- feature_2 >  13.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 24.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 15
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  24.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 46.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  46.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |--- feature_0 >  3.50
# |   |   |   |   |   |   |   |--- feature_3 <= 287.50
# |   |   |   |   |   |   |   |   |--- feature_57 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 10.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_33 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 17
# |   |   |   |   |   |   |   |   |   |   |--- feature_33 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  10.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 15.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  15.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |--- feature_57 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 113.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 12.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 18
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  12.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  113.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |--- feature_3 >  287.50
# |   |   |   |   |   |   |   |   |--- feature_45 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_41 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |--- feature_41 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |--- feature_45 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 390.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  390.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 428.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  428.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |--- feature_0 >  4.50
# |   |   |   |   |   |   |--- feature_2 <= 17.50
# |   |   |   |   |   |   |   |--- feature_2 <= 14.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 10.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 6.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 2.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  2.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  6.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 7.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  7.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |--- feature_2 >  10.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 105.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 97.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  97.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  105.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 20.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  20.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |--- feature_2 >  14.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 24.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 25.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 15.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  15.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  25.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- feature_4 >  24.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 57.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 33.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  33.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  57.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |--- feature_2 >  17.50
# |   |   |   |   |   |   |   |--- feature_2 <= 18.50
# |   |   |   |   |   |   |   |   |--- feature_29 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 390.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  390.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 495.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  495.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |--- feature_29 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 31.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 25.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  25.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  31.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 53.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  53.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |--- feature_2 >  18.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 166.00
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |--- feature_3 >  166.00
# |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |--- feature_35 >  0.50
# |   |   |   |--- feature_0 <= 3.50
# |   |   |   |   |--- feature_2 <= 14.50
# |   |   |   |   |   |--- feature_2 <= 10.50
# |   |   |   |   |   |   |--- feature_2 <= 2.50
# |   |   |   |   |   |   |   |--- feature_2 <= 1.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 9.50
# |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |--- feature_5 >  9.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 11.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 22.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  22.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  11.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |--- feature_2 >  1.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 2.00
# |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |--- feature_0 >  2.00
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 175.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 12.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  12.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  175.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |--- feature_2 >  2.50
# |   |   |   |   |   |   |   |--- feature_0 <= 2.00
# |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |--- feature_0 >  2.00
# |   |   |   |   |   |   |   |   |--- feature_3 <= 308.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 299.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  299.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |--- feature_3 >  308.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 7.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 10.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  10.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  7.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |--- feature_2 >  10.50
# |   |   |   |   |   |   |--- feature_0 <= 2.00
# |   |   |   |   |   |   |   |--- feature_3 <= 60.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 6.00
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 43.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  43.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |--- feature_5 >  6.00
# |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |--- feature_3 >  60.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 13.50
# |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |--- feature_2 >  13.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 34.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  34.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |--- feature_0 >  2.00
# |   |   |   |   |   |   |   |--- feature_4 <= 5.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 9.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 32.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  32.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 104.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  104.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |--- feature_5 >  9.50
# |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |--- feature_4 >  5.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 12.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 15.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 11.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  11.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  15.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 241.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  241.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- feature_2 >  12.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 105.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 7.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  7.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  105.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 15.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  15.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |--- feature_2 >  14.50
# |   |   |   |   |   |--- feature_5 <= 30.00
# |   |   |   |   |   |   |--- feature_4 <= 14.50
# |   |   |   |   |   |   |   |--- feature_3 <= 17.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 15.50
# |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |--- feature_2 >  15.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 5.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 8.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  8.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  5.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |--- feature_3 >  17.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 75.50
# |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |--- feature_3 >  75.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 87.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  87.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |--- feature_4 >  14.50
# |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |--- feature_5 >  30.00
# |   |   |   |   |   |   |--- feature_3 <= 219.00
# |   |   |   |   |   |   |   |--- feature_3 <= 39.00
# |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |--- feature_3 >  39.00
# |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |--- feature_3 >  219.00
# |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |--- feature_0 >  3.50
# |   |   |   |   |--- feature_2 <= 15.50
# |   |   |   |   |   |--- feature_3 <= 187.50
# |   |   |   |   |   |   |--- feature_2 <= 2.50
# |   |   |   |   |   |   |   |--- feature_2 <= 1.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 26.00
# |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |--- feature_4 >  26.00
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 47.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  47.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |--- feature_2 >  1.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 28.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 26.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 48.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  48.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  26.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |--- feature_3 >  28.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 14.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 12.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  12.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  14.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |--- feature_2 >  2.50
# |   |   |   |   |   |   |   |--- feature_5 <= 31.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 2.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 6.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  6.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |--- feature_3 >  2.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 10.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 184.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  184.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  10.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 13.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  13.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |--- feature_5 >  31.50
# |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |--- feature_3 >  187.50
# |   |   |   |   |   |   |--- feature_4 <= 8.50
# |   |   |   |   |   |   |   |--- feature_5 <= 13.00
# |   |   |   |   |   |   |   |   |--- feature_2 <= 8.00
# |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |--- feature_2 >  8.00
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 325.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  325.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 329.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  329.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |--- feature_5 >  13.00
# |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |--- feature_4 >  8.50
# |   |   |   |   |   |   |   |--- feature_4 <= 22.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 10.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 1201.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  1201.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 12.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  12.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_2 >  10.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 364.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 321.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  321.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  364.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |--- feature_4 >  22.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 30.00
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  1.50
# ...
# |   |   |   |   |   |   |   |   |--- feature_3 <= 31.00
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 7.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  7.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |--- feature_3 >  31.00
# |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |--- feature_3 >  48.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 6.00
# |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |--- feature_4 >  6.00
# |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |--- feature_3 >  70.50
# |   |   |   |   |   |   |--- feature_3 <= 83.00
# |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |--- feature_3 >  83.00
# |   |   |   |   |   |   |   |--- feature_4 <= 30.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 543.00
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 18.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  18.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 176.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  176.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_3 >  543.00
# |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |--- feature_4 >  30.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 17.50
# |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |--- feature_5 >  17.50
# |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |--- feature_2 >  14.50
# |   |   |   |   |--- feature_4 <= 15.50
# |   |   |   |   |   |--- feature_4 <= 7.50
# |   |   |   |   |   |   |--- feature_0 <= 2.00
# |   |   |   |   |   |   |   |--- feature_3 <= 24.50
# |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |--- feature_3 >  24.50
# |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |--- feature_0 >  2.00
# |   |   |   |   |   |   |   |--- feature_3 <= 80.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 3.00
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 23.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  23.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |--- feature_4 >  3.00
# |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |--- feature_3 >  80.50
# |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |--- feature_4 >  7.50
# |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |--- feature_4 >  15.50
# |   |   |   |   |   |--- feature_3 <= 35.50
# |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |--- feature_3 >  35.50
# |   |   |   |   |   |   |--- feature_3 <= 119.00
# |   |   |   |   |   |   |   |--- feature_3 <= 57.50
# |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |--- feature_3 >  57.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 69.00
# |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |--- feature_3 >  69.00
# |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |--- feature_3 >  119.00
# |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |--- feature_0 >  3.50
# |   |   |   |--- feature_3 <= 603.00
# |   |   |   |   |--- feature_2 <= 12.50
# |   |   |   |   |   |--- feature_4 <= 21.50
# |   |   |   |   |   |   |--- feature_3 <= 534.00
# |   |   |   |   |   |   |   |--- feature_3 <= 5.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 6.00
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |--- feature_2 >  6.00
# |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |--- feature_3 >  5.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 6.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 5.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  5.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 9.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  9.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |--- feature_3 >  6.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 10.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 15
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  10.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 18.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  18.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |--- feature_3 >  534.00
# |   |   |   |   |   |   |   |--- feature_2 <= 6.00
# |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |--- feature_2 >  6.00
# |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |--- feature_4 >  21.50
# |   |   |   |   |   |   |--- feature_2 <= 11.50
# |   |   |   |   |   |   |   |--- feature_3 <= 292.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 258.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 248.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 241.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  241.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  248.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 11.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  11.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |--- feature_3 >  258.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 262.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  262.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |--- feature_3 >  292.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 335.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 10.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  10.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 311.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  311.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |--- feature_3 >  335.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 382.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 8.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  8.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  382.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 590.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  590.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |--- feature_2 >  11.50
# |   |   |   |   |   |   |   |--- feature_3 <= 416.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 59.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 46.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  46.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |--- feature_3 >  59.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 10.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 26.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  26.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  10.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 307.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  307.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |--- feature_3 >  416.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 518.00
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 479.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  479.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |--- feature_3 >  518.00
# |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |--- feature_2 >  12.50
# |   |   |   |   |   |--- feature_3 <= 5.50
# |   |   |   |   |   |   |--- feature_2 <= 15.50
# |   |   |   |   |   |   |   |--- feature_2 <= 14.00
# |   |   |   |   |   |   |   |   |--- feature_4 <= 7.50
# |   |   |   |   |   |   |   |   |   |--- value: [1.80]
# |   |   |   |   |   |   |   |   |--- feature_4 >  7.50
# |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |--- feature_2 >  14.00
# |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |--- feature_2 >  15.50
# |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |--- feature_3 >  5.50
# |   |   |   |   |   |   |--- feature_3 <= 16.50
# |   |   |   |   |   |   |   |--- feature_4 <= 3.50
# |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |--- feature_4 >  3.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 5.50
# |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |   |--- feature_4 >  5.50
# |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |--- feature_3 >  16.50
# |   |   |   |   |   |   |   |--- feature_3 <= 26.00
# |   |   |   |   |   |   |   |   |--- feature_2 <= 14.00
# |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |   |--- feature_2 >  14.00
# |   |   |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |   |   |--- feature_3 >  26.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 5.00
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 87.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 14.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  14.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  87.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 12.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  12.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- feature_0 >  5.00
# |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |--- feature_3 >  603.00
# |   |   |   |   |--- feature_4 <= 2.00
# |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |--- feature_4 >  2.00
# |   |   |   |   |   |--- feature_4 <= 23.50
# |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |--- feature_4 >  23.50
# |   |   |   |   |   |   |--- feature_4 <= 26.50
# |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |--- feature_4 >  26.50
# |   |   |   |   |   |   |   |--- value: [3.00]
# |   |--- feature_4 >  39.50
# |   |   |--- feature_3 <= 168.00
# |   |   |   |--- feature_4 <= 48.50
# |   |   |   |   |--- feature_2 <= 2.50
# |   |   |   |   |   |--- feature_5 <= 12.50
# |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |--- feature_5 >  12.50
# |   |   |   |   |   |   |--- feature_0 <= 3.50
# |   |   |   |   |   |   |   |--- feature_5 <= 17.00
# |   |   |   |   |   |   |   |   |--- feature_3 <= 128.50
# |   |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |   |   |--- feature_3 >  128.50
# |   |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |--- feature_5 >  17.00
# |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |--- feature_0 >  3.50
# |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |--- feature_2 >  2.50
# |   |   |   |   |   |--- feature_2 <= 17.00
# |   |   |   |   |   |   |--- feature_4 <= 46.50
# |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |--- feature_4 >  46.50
# |   |   |   |   |   |   |   |--- feature_2 <= 6.50
# |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |--- feature_2 >  6.50
# |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |--- feature_2 >  17.00
# |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |--- feature_4 >  48.50
# |   |   |   |   |--- feature_0 <= 5.00
# |   |   |   |   |   |--- feature_3 <= 143.00
# |   |   |   |   |   |   |--- feature_5 <= 10.00
# |   |   |   |   |   |   |   |--- feature_2 <= 12.50
# |   |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |   |   |--- feature_2 >  12.50
# |   |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |--- feature_5 >  10.00
# |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |--- feature_3 >  143.00
# |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |--- feature_0 >  5.00
# |   |   |   |   |   |--- feature_4 <= 65.00
# |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |--- feature_4 >  65.00
# |   |   |   |   |   |   |--- value: [1.00]
# |   |   |--- feature_3 >  168.00
# |   |   |   |--- feature_0 <= 2.00
# |   |   |   |   |--- feature_5 <= 5.50
# |   |   |   |   |   |--- feature_2 <= 10.50
# |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |--- feature_2 >  10.50
# |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |--- feature_5 >  5.50
# |   |   |   |   |   |--- feature_4 <= 64.50
# |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |--- feature_4 >  64.50
# |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |--- feature_0 >  2.00
# |   |   |   |   |--- feature_5 <= 6.50
# |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |--- feature_5 >  6.50
# |   |   |   |   |   |--- feature_2 <= 2.50
# |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |--- feature_2 >  2.50
# |   |   |   |   |   |   |--- value: [2.00]

# %% [markdown]
# ### Results:

# %% [markdown]
# #### Model - Random Forest
#
# Model 1 | MAE - 0.23 | Accuracy - 84.63%
#
# Model 2 | MAE - 0.2  | Accuracy - 86.61%
#
# #### Model - Decision Tree
#
# Model 1 | MAE - 0.27 | Model accuracy score with criterion entropy: 0.7393
#
# Model 2 | MAE - 0.33 | Model accuracy score with criterion entropy: 0.6788

# %% [markdown]
# ### Conclusion :
#
# Successfully completed the steps assigned for this assignment. From the results above we can see that the model with highest accuracy(86.61%) and lowest MAE(0.2) is Model 2 of Random Forest.

# %% [markdown]
# #### References :
# - https://towardsdatascience.com/an-exhaustive-guide-to-classification-using-decision-trees-8d472e77223f
# - https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html
# - https://towardsdatascience.com/random-forest-in-python-24d0893d51c0
# - https://mljar.com/blog/visualize-decision-tree/
